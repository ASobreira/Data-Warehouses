# %% [markdown]
# # IPAI Project

# %% [markdown]
# ## Group 1
# #### Tiago Rodrigues (49593)
# #### Ivo Oliveira (50301)
# #### Martim Silva (51304)
# #### Alexandre Sobreira (59451)

# %% [markdown]
# 1st Phase - Point 1

# %%
import datetime
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
customers_USA = pd.read_csv("../data/Raw_Tables/customers_USA_RAW.csv", delimiter=",", encoding="windows-1252")
customers_USA = pd.DataFrame(customers_USA)
orders = pd.read_excel("../data/Raw_Tables/orders_RAW.xlsx", sheet_name="Orders")
orders = pd.DataFrame(orders)
returns = pd.read_csv("../data/Raw_Tables/returns_RAW.csv")
returns = pd.DataFrame(returns)
sellers = pd.read_csv("../data/Raw_Tables/sellers_RAW.csv", delimiter=";")
sellers = pd.DataFrame(sellers)
holiday_USA = pd.read_csv("../data/Raw_Tables/holiday_USA_RAW.csv")
holiday_USA = pd.DataFrame(holiday_USA)
GDP_USA = pd.read_csv("../data/Raw_Tables/GDP_USA_RAW.csv")
GDP_USA = pd.DataFrame(GDP_USA)

# %% [markdown]
# # Datasets and Tables

# %% [markdown]
# ## Global Superstore Orders 2016.xlsx

# %% [markdown]
# ### Orders

# %%
orders.head()
#orders.tail()
#orders.info()
#orders.isna().sum()
#orders.duplicated().sum()

#num_features = orders.describe()
#num_features

#for c in num_features:
#    print(c , ":" ,orders[c].nunique())
    
#cat_features = [f for f in orders.columns if(orders[f].dtype=='object')]
#orders[cat_features].describe()

#orders["Order Date"].describe()

#costumers['Order Date'] = pd.to_datetime(costumers['Order Date'])
#costumers['Ship Date'] = pd.to_datetime(costumers['Ship Date'])
# Out:
#    Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0   48313  AE-2012-PO8865138-41184 2012-10-02 2012-10-06  Standard Class
# 1   48312  AE-2012-PO8865138-41184 2012-10-02 2012-10-06  Standard Class
# 2   47298  AE-2014-EB4110138-41926 2014-10-14 2014-10-14        Same Day
# 3   47297  AE-2014-EB4110138-41926 2014-10-14 2014-10-14        Same Day
# 4   48617  AE-2014-MY7380138-42004 2014-12-31 2015-01-03    Second Class
#
#   Customer ID      Customer Name    Segment  Postal Code            City  ...  \
# 0  PO-8865138  Patrick O'Donnell   Consumer          NaN           Ajman  ...
# 1  PO-8865138  Patrick O'Donnell   Consumer          NaN           Ajman  ...
# 2  EB-4110138     Eugene Barchas   Consumer          NaN  Ras al Khaymah  ...
# 3  EB-4110138     Eugene Barchas   Consumer          NaN  Ras al Khaymah  ...
# 4  MY-7380138    Maribeth Yedwab  Corporate          NaN  Ras al Khaymah  ...
#
# ...

# %% [markdown]
# #### Viz's

# %%
colors = ['#1192AA','#00B8C0', '#73D4D3', '#90F2F0']

# %% [markdown]
# ##### Ship Mode

# %%
fig = px.bar(x = orders['Ship Mode'].value_counts().index, y = orders['Ship Mode'].value_counts(),
             color = orders['Ship Mode'].value_counts().index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Shipping Mode",
    yaxis_title="Number of Orders",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "Frequency of Orders by Shipping Modes",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ##### Segment

# %%
fig = px.bar(x = orders['Segment'].value_counts().index, y = orders['Segment'].value_counts(),
             color = orders['Segment'].value_counts().index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Segment",
    yaxis_title="Number of Orders",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "Frequency of Orders by Segment",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ##### Region

# %%
fig = px.bar(x = orders['Region'].value_counts().index, y = orders['Region'].value_counts(),
             color = orders['Region'].value_counts().index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Region",
    yaxis_title="Number of Orders",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "Frequency of Orders by Region",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ##### Category

# %%
fig = px.bar(x = orders['Category'].value_counts().index, y = orders['Category'].value_counts(),
             color = orders['Category'].value_counts().index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Number of Orders",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "Frequency of Orders by Category",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ##### sub category

# %%
fig = px.bar(x = orders['Sub-Category'].value_counts().index, y = orders['Sub-Category'].value_counts(),
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Sub-Category",
    yaxis_title="Number of Orders",
    font = dict(
            size = 14
            ),    
    title={
        #'text': "Frequency of Orders by Sub-Category",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ### Sellers

# %%
#sellers.head()
#sellers.tail()
#sellers.info()
#sellers.isna().sum()
#sellers.duplicated().sum()

num_features = sellers.describe()
num_features

#for c in num_features:
#    print(c , ":" ,sellers[c].nunique())
    
#cat_features = [f for f in sellers.columns if(sellers[f].dtype=='object')]
#sellers[cat_features].describe()

#sellers["Order Date"].describe()

#sellers['Order Date'] = pd.to_datetime(sellers['Order Date'])
#sellers['Ship Date'] = pd.to_datetime(sellers['Ship Date'])
# Out:
#                    Person     Region
# count                  24         24
# unique                 24         24
# top     Marilène Rousseau  Caribbean
# freq                    1          1

# %% [markdown]
# ## Global Superstore Returns 2016.csv

# %% [markdown]
# ### Returns

# %%
#returns.head()
#returns.tail()
#returns.info()
#returns.isna().sum()
#returns.duplicated().sum()

num_features = returns.describe()
num_features

#for c in num_features:
#    print(c , ":" ,returns[c].nunique())
    
#cat_features = [f for f in returns.columns if(returns[f].dtype=='object')]
#returns[cat_features].describe()

#returns["Returned"].describe()

#returns['Order Date'] = pd.to_datetime(returns['Order Date'])
#returns['Ship Date'] = pd.to_datetime(returns['Ship Date'])
# Out:
#        Returned                  Order ID          Region
# count      1079                      1079            1079
# unique        1                      1079              24
# top         Yes  CA-2012-SA20830140-41210  Western Europe
# freq       1079                         1             121

# %% [markdown]
# ## Superstore Dataset

# %% [markdown]
# ### Costumers_USA

# %%
#customers_USA.head()
#customers_USA.tail()
#ustomers_USA.info()
#customers_USA.isna().sum()
#customers_USA.duplicated().sum()

num_features = customers_USA.describe()
num_features

#for c in num_features:
#    print(c , ":" ,customers_USA[c].nunique())
    
#cat_features = [f for f in customers_USA.columns if(customers_USA[f].dtype=='object')]
#customers_USA[cat_features].describe()

#customers_USA["Order Date"].describe()

#customers_USA['Order Date'] = pd.to_datetime(customers_USA['Order Date'])
#customers_USA['Ship Date'] = pd.to_datetime(customers_USA['Ship Date'])
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# #### Viz's

# %% [markdown]
# ##### States

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
# Create new column with State Abbreviations
customers_USA['State_abb'] = customers_USA['State'].replace(us_state_to_abbrev)

# Create Choropleth object
choro = go.Choropleth(
    locations= customers_USA['State_abb'].value_counts().index, # Spatial coordinates
    z = customers_USA['State_abb'].value_counts(), # costumers_USA to be color-coded
    locationmode = 'USA-states',
    colorscale = 'teal', zmin = 1, zmax = 1000,
    text = customers_USA['State_abb']
)

# Create Figure object
fig = go.Figure(data=choro, layout=go.Layout(
    font = dict(
            size = 14
            ),    
    title={
       # 'text': "Number of Customers by State Map",
        'y':0.95,
        'x':0.5
        },
    geo_scope='usa' # limit map scope to USA
))

# Display Figure
fig.show()

# %%
top_cities = customers_USA['State'].value_counts().head(25)


fig = px.bar(x=top_cities.index, y=top_cities.values,
             color=top_cities.index,
             template='simple_white', color_discrete_sequence=colors)

# Set chart title and x/y axis labels
fig.update_layout(
    xaxis_title="State",
    yaxis_title="Number of Customers",
    showlegend=False,
    font=dict(
        size=14
    ),
    title={
        #'text': "Number of Customers by State (Top 25)",
        'y': 0.95,
        'x': 0.5
    },
    xaxis_tickangle=-45, # Rotate x-axis labels for better visibility
)

# Display Figure
fig.show()

# %% [markdown]
# ##### Citys

# %%
top_cities = customers_USA['City'].value_counts().head(25)


fig = px.bar(x=top_cities.index, y=top_cities.values,
             color=top_cities.index,
             template='simple_white', color_discrete_sequence=colors)

# Set chart title and x/y axis labels
fig.update_layout(
    xaxis_title="City",
    yaxis_title="Number of Customers",
    showlegend=False,
    font=dict(
        size=14
    ),
    title={
        #'text': "Number of Customers by City (Top 25)",
        'y': 0.95,
        'x': 0.5
    },
    xaxis_tickangle=-45, # Rotate x-axis labels for better visibility
)

# Display Figure
fig.show()

# %% [markdown]
# ##### Region

# %%
top_cities = customers_USA['Region'].value_counts()


fig = px.bar(x=top_cities.index, y=top_cities.values,
             color=top_cities.index,
             template='simple_white', color_discrete_sequence=colors)

# Set chart title and x/y axis labels
fig.update_layout(
    xaxis_title="Region",
    yaxis_title="Number of Customers",
    showlegend=False,
    font=dict(
        size=14
    ),
    title={
        #'text': "Number of Customers by Region (Top 25)",
        'y': 0.95,
        'x': 0.5
    },
    xaxis_tickangle=-45, # Rotate x-axis labels for better visibility
)

# Display Figure
fig.show()

# %% [markdown]
# ## US Holiday Dates (2004 - 2021)

# %% [markdown]
# ## holiday_USA

# %%
#holiday_USA.head()
#holiday_USA.tail()
#holiday_USA.info()
#holiday_USA.isna().sum()
#holiday_USA.duplicated().sum()

num_features = holiday_USA.describe()
num_features

#for c in num_features:
#    print(c , ":" ,holiday_USA[c].nunique())
    
#cat_features = [f for f in holiday_USA.columns if(holiday_USA[f].dtype=='object')]
#holiday_USA[cat_features].describe()

#holiday_USA["Holiday"].unique()

#costumers['Order Date'] = pd.to_datetime(costumers['Order Date'])
#costumers['Ship Date'] = pd.to_datetime(costumers['Ship Date'])
# Out:
#             Month         Day         Year
# count  342.000000  342.000000   342.000000
# mean     7.263158   15.853801  2012.500000
# std      3.899889    9.653330     5.195729
# min      1.000000    1.000000  2004.000000
# 25%      4.000000    6.000000  2008.000000
# 50%      9.000000   16.500000  2012.500000
# 75%     11.000000   24.000000  2017.000000
# max     12.000000   31.000000  2021.000000

# %% [markdown]
# ## Highest GDP Counties in the USA

# %% [markdown]
# ### GDP_USA

# %%
#GDP_USA.head()
#GDP_USA.tail()
GDP_USA.info()
#GDP_USA.isna().sum()
#GDP_USA.duplicated().sum()

num_features = GDP_USA.describe()
num_features

#for c in num_features:
#    print(c , ":" ,GDP_USA[c].nunique())
    
#cat_features = [f for f in GDP_USA.columns if(GDP_USA[f].dtype=='object')]
#GDP_USA[cat_features].describe()

#GDP_USA["Year"].unique()

#costumers['Order Date'] = pd.to_datetime(costumers['Order Date'])
#costumers['Ship Date'] = pd.to_datetime(costumers['Ship Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55501 entries, 0 to 55500
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            55501 non-null  int64
#  1   Year             55501 non-null  int64
#  2   Region           55501 non-null  object
#  3   SUB_REGION       55501 non-null  object
#  4   State            55501 non-null  object
#  5   County           55501 non-null  object
#  6   GDP (Chained $)  55501 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 3.0+ MB
#               index          Year  GDP (Chained $)
# count  55501.000000  55501.000000     5.550100e+04
# mean   27750.000000   2009.494207     5.053577e+09
# std    16021.902982      5.182892     2.154341e+10
# min        0.000000   2001.000000     9.948000e+06
# 25%    13875.000000   2005.000000     3.366970e+08
# 50%    27750.000000   2009.000000     8.606620e+08
# ...

# %% [markdown]
# #### Viz's

# %%
GDP_USA['GDP (Chained $)'] = pd.to_numeric(GDP_USA['GDP (Chained $)'], errors='coerce').apply(lambda x: '{:,.0f}'.format(x))

# %%
GDP_USA['GDP (Chained $)']
# Out:
# 0          954,588,000
# 1        3,929,753,000
# 2          813,278,000
# 3          292,693,000
# 4          810,381,000
#              ...
# 55496      454,537,000
# 55497      275,583,000
# 55498      685,543,000
# 55499      127,499,000
# 55500      172,856,000
# Name: GDP (Chained $), Length: 55501, dtype: object

# %% [markdown]
# ##### States

# %%
## CREATE NEW TABLE
# group by category
profit_per_states = GDP_USA[['State', 'GDP (Chained $)']].groupby('State').sum().head(25)

# sort values by Sales
profit_per_states.sort_values(by='GDP (Chained $)', ascending=False, inplace=True)


# bar chart
fig = px.bar(x = profit_per_states.index,
             y = profit_per_states['GDP (Chained $)'],
             color = profit_per_states.index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="State",
    yaxis_title="GDP",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "GDP by State(25)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()

# %% [markdown]
# ##### Region

# %%
## CREATE NEW TABLE
# group by category
profit_per_states = GDP_USA[['Region', 'GDP (Chained $)']].groupby('Region').sum()

# sort values by Sales
profit_per_states.sort_values(by='GDP (Chained $)', ascending=False, inplace=True)

# bar chart
fig = px.bar(x = profit_per_states.index,
             y = profit_per_states['GDP (Chained $)'],
             color = profit_per_states.index,
             template = 'simple_white', color_discrete_sequence = colors)

#Set Title and x/y axis labels
fig.update_layout(
    xaxis_title="Region",
    yaxis_title="GDP",
    showlegend = False,
    font = dict(
            size = 14
            ),    
    title={
        #'text': "GDP by Region(25)",
        'y':0.95,
        'x':0.5
        }
    )

fig.show()
